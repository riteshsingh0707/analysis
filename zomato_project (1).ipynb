# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Indian-Resturants (1).csv')

# %%
df
# Out:
#           res_id                            name      establishment  \
# 0        3400299                     Bikanervala    ['Quick Bites']
# 1        3400005  Mama Chicken Mama Franky House    ['Quick Bites']
# 2        3401013                   Bhagat Halwai    ['Quick Bites']
# 3        3400290                   Bhagat Halwai    ['Quick Bites']
# 4        3401744     The Salt Cafe Kitchen & Bar  ['Casual Dining']
# ...          ...                             ...                ...
# 211939   3202251  Kali Mirch Cafe And Restaurant  ['Casual Dining']
# 211940   3200996                      Raju Omlet    ['Quick Bites']
# 211941  18984164                The Grand Thakar  ['Casual Dining']
# 211942   3201138                          Subway    ['Quick Bites']
# 211943  18879846     Freshco's - The Health Cafe           ['Café']
#
#                                                       url  \
# 0       https://www.zomato.com/agra/bikanervala-khanda...
# ...

# %%
df.shape
# Out:
# (211944, 26)

# %%
df.head()
# Out:
#     res_id                            name      establishment  \
# 0  3400299                     Bikanervala    ['Quick Bites']
# 1  3400005  Mama Chicken Mama Franky House    ['Quick Bites']
# 2  3401013                   Bhagat Halwai    ['Quick Bites']
# 3  3400290                   Bhagat Halwai    ['Quick Bites']
# 4  3401744     The Salt Cafe Kitchen & Bar  ['Casual Dining']
#
#                                                  url  \
# 0  https://www.zomato.com/agra/bikanervala-khanda...
# 1  https://www.zomato.com/agra/mama-chicken-mama-...
# 2  https://www.zomato.com/agra/bhagat-halwai-2-sh...
# 3  https://www.zomato.com/agra/bhagat-halwai-civi...
# 4  https://www.zomato.com/agra/the-salt-cafe-kitc...
#
#                                              address  city  city_id  \
# 0  Kalyani Point, Near Tulsi Cinema, Bypass Road,...  Agra       34
# 1        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra       34
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211944 entries, 0 to 211943
# Data columns (total 26 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   res_id                211944 non-null  int64
#  1   name                  211944 non-null  object
#  2   establishment         211944 non-null  object
#  3   url                   211944 non-null  object
#  4   address               211810 non-null  object
#  5   city                  211944 non-null  object
#  6   city_id               211944 non-null  int64
#  7   locality              211944 non-null  object
#  8   latitude              211944 non-null  float64
#  9   longitude             211944 non-null  float64
#  10  zipcode               48757 non-null   object
#  11  country_id            211944 non-null  int64
#  12  locality_verbose      211944 non-null  object
#  13  cuisines              210553 non-null  object
# ...

# %%
df.describe()
# Out:
#              res_id        city_id       latitude      longitude  country_id  \
# count  2.119440e+05  211944.000000  211944.000000  211944.000000    211944.0
# mean   1.349411e+07    4746.785434      21.499758      77.615276         1.0
# std    7.883722e+06    5568.766386      22.781331       7.500104         0.0
# min    5.000000e+01       1.000000       0.000000       0.000000         1.0
# 25%    3.301027e+06      11.000000      15.496071      74.877961         1.0
# 50%    1.869573e+07      34.000000      22.514494      77.425971         1.0
# 75%    1.881297e+07   11306.000000      26.841667      80.219323         1.0
# max    1.915979e+07   11354.000000   10000.000000      91.832769         1.0
#
#        average_cost_for_two    price_range  aggregate_rating          votes  \
# count         211944.000000  211944.000000     211944.000000  211944.000000
# mean             595.812229       1.882535          3.395937     378.001864
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# zipcode                 163187
# timings                   3874
# cuisines                  1391
# address                    134
# opentable_support           48
# city                         0
# name                         0
# establishment                0
# url                          0
# res_id                       0
# longitude                    0
# latitude                     0
# locality                     0
# city_id                      0
# locality_verbose             0
# average_cost_for_two         0
# price_range                  0
# country_id                   0
# currency                     0
# highlights                   0
# rating_text                  0
# aggregate_rating             0
# votes                        0
# photo_count                  0
# delivery                     0
# takeaway                     0
# dtype: int64

# %%
#handling all missing data
# Drop columns not needed
df.drop(columns=['zipcode','opentable_support'],inplace=True)

# %%
# Fill missing 'timings' and 'address'
df['timings'].fillna('not Available',inplace=True)
df['address'].fillna('not Available',inplace=True)
# Out:
# /tmp/ipython-input-3941364142.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['timings'].fillna('not Available',inplace=True)
# /tmp/ipython-input-3941364142.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
# Fill missing 'cuisines' with 'Unknown'
df['cuisines'].fillna('Unknown', inplace=True)
# Out:
# /tmp/ipython-input-136826808.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cuisines'].fillna('Unknown', inplace=True)

# %%
# Recheck missing data
df.isnull().sum().sort_values(ascending=False)
# Out:
# res_id                  0
# name                    0
# establishment           0
# url                     0
# address                 0
# city                    0
# city_id                 0
# locality                0
# latitude                0
# longitude               0
# country_id              0
# locality_verbose        0
# cuisines                0
# timings                 0
# average_cost_for_two    0
# price_range             0
# currency                0
# highlights              0
# aggregate_rating        0
# rating_text             0
# votes                   0
# photo_count             0
# delivery                0
# takeaway                0
# dtype: int64

# %%
#Distribution of Aggregate Ratings
plt.figure(figsize=(10, 6))
sns.histplot(df['aggregate_rating'], bins=20, kde=True, color='skyblue')
plt.title("Distribution of Restaurant Ratings")
plt.xlabel("Aggregate Rating")
plt.ylabel("Number of Restaurants")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='rating_text', order=df['rating_text'].value_counts().nlargest(10).index, palette='Set2')
plt.title("Count of Restaurants by Rating Category")
plt.xlabel("Rating Text")
plt.ylabel("Number of Restaurants")
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipython-input-4191165171.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='rating_text', order=df['rating_text'].value_counts().nlargest(10).index, palette='Set2')

# %%
average_rating = df['aggregate_rating'].mean()
print("Average Rating of All Restaurants:", round(average_rating, 2))
# Out:
# Average Rating of All Restaurants: 3.4

# %%
top_rated=df.nlargest(5,'aggregate_rating')
print("🏆 Top Rated Restaurants:")
print(top_rated.head())
# Out:
# 🏆 Top Rated Restaurants:
#       res_id                         name      establishment  \
# 4    3401744  The Salt Cafe Kitchen & Bar  ['Casual Dining']
# 186  3401744  The Salt Cafe Kitchen & Bar  ['Casual Dining']
# 300  3401744  The Salt Cafe Kitchen & Bar  ['Casual Dining']
# 600  3401744  The Salt Cafe Kitchen & Bar  ['Casual Dining']
# 813  3401744  The Salt Cafe Kitchen & Bar  ['Casual Dining']
#
#                                                    url  \
# 4    https://www.zomato.com/agra/the-salt-cafe-kitc...
# 186  https://www.zomato.com/agra/the-salt-cafe-kitc...
# 300  https://www.zomato.com/agra/the-salt-cafe-kitc...
# 600  https://www.zomato.com/agra/the-salt-cafe-kitc...
# 813  https://www.zomato.com/agra/the-salt-cafe-kitc...
#
#                                          address  city  city_id locality  \
# 4    1C,3rd Floor, Fatehabad Road, Tajganj, Agra  Agra       34  Tajganj
# 186  1C,3rd Floor, Fatehabad Road, Tajganj, Agra  Agra       34  Tajganj
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(
    data=top_rated.head(5),
    x='aggregate_rating',
    y='name',
    hue='city',
    dodge=False,
    palette='Set2'
)
# Out:
# <Axes: xlabel='aggregate_rating', ylabel='name'>

# %%
# Top 5 highest rated restaurants
top_rated = df[df['aggregate_rating'] == df['aggregate_rating'].max()][['name', 'city', 'aggregate_rating']]
print("🏆 Top Rated Restaurants:")
print(top_rated.head())
# Out:
# 🏆 Top Rated Restaurants:
#                             name  city  aggregate_rating
# 4    The Salt Cafe Kitchen & Bar  Agra               4.9
# 186  The Salt Cafe Kitchen & Bar  Agra               4.9
# 300  The Salt Cafe Kitchen & Bar  Agra               4.9
# 600  The Salt Cafe Kitchen & Bar  Agra               4.9
# 813  The Salt Cafe Kitchen & Bar  Agra               4.9

# %%
# Count top 10 cuisines
cuisine_counts=df['cuisines'].value_counts().head(10)
print("Top 10 Cuisines:")
print(cuisine_counts)
# Out:
# Top 10 Cuisines:
# cuisines
# North Indian             15996
# Fast Food                 6721
# Cafe                      6190
# North Indian, Chinese     5820
# South Indian              5217
# Pizza, Fast Food          4075
# Bakery                    3238
# Street Food               2837
# Biryani                   2118
# Chinese                   2116
# Name: count, dtype: int64

# %%
# Plot top cuisines
plt.figure(figsize=(10, 5))
sns.barplot(x=cuisine_counts.values, y=cuisine_counts.index, palette='magma')
plt.title("Top 10 Most Popular Cuisines")
plt.xlabel("Number of Restaurants")
plt.ylabel("Cuisine")
plt.show()
# Out:
# /tmp/ipython-input-2143438365.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=cuisine_counts.values, y=cuisine_counts.index, palette='magma')

# %%
#Correlation Between Cuisine Variety & Rating
# Count number of cuisines per restaurant
df['cuisine_variety'] = df['cuisines'].apply(lambda x: len(x.split(',')) if isinstance(x, str) else 0)
# Correlation coefficient
correlation = df['cuisine_variety'].corr(df['aggregate_rating'])
print("Correlation between cuisine variety and rating:", round(correlation, 3))
# Out:
# Correlation between cuisine variety and rating: 0.24

# %%
# Boxplot: variety vs rating
plt.figure(figsize=(8, 5))
sns.boxplot(x='cuisine_variety', y='aggregate_rating', data=df)
plt.title("Cuisine Variety vs Aggregate Rating")
plt.xlabel("Number of Cuisines Offered")
plt.ylabel("Aggregate Rating")
plt.grid(True)
plt.show()

# %%
#Price Range vs Rating
plt.figure(figsize=(8, 5))
sns.boxplot(x='price_range', y='aggregate_rating', data=df, palette='pastel')
plt.title("Price Range vs Aggregate Rating")
plt.xlabel("Price Range (1 = Low, 4 = High)")
plt.ylabel("Aggregate Rating")
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-3931175746.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='price_range', y='aggregate_rating', data=df, palette='pastel')

# %%
# Grouping average cost by price range
avg_cost_by_price = df.groupby('price_range')['average_cost_for_two'].mean()

# Plotting
plt.figure(figsize=(8, 5))
sns.barplot(x=avg_cost_by_price.index, y=avg_cost_by_price.values, palette='coolwarm')
plt.title("Average Cost for Two in Each Price Range")
plt.xlabel("Price Range (1 = Low, 4 = High)")
plt.ylabel("Average Cost for Two (₹)")
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-3413831471.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_cost_by_price.index, y=avg_cost_by_price.values, palette='coolwarm')

# %%
correlation = df['price_range'].corr(df['aggregate_rating'])
print("Correlation between price range and rating:", round(correlation, 3))
# Out:
# Correlation between price range and rating: 0.252

# %%
 #Online Order and Table Booking Analysis
#Assuming
#delivery = 1 means Online Order is available
#delivery = -1 means Not available
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 4))
sns.boxplot(x='delivery', y='aggregate_rating', data=df, palette='Set2')
plt.title("Online Order Availability vs Ratings")
plt.xlabel("Online Order (1 = Yes, -1 = No)")
plt.ylabel("Aggregate Rating")
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-108737888.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='delivery', y='aggregate_rating', data=df, palette='Set2')

# %%
# Distribution of Restaurants with Table Booking
#We’ll use the highlights column to detect whether "Table booking" is mentioned.
# Create a new column indicating if table booking is available
df['has_table_booking'] = df['highlights'].apply(lambda x: 'Table booking' in x)

# Count of restaurants offering table booking
table_booking_counts = df['has_table_booking'].value_counts()

# Bar plot of distribution
plt.figure(figsize=(6, 4))
sns.countplot(x='has_table_booking', data=df, palette='pastel')
plt.title("Distribution of Restaurants Offering Table Booking")
plt.xlabel("Table Booking Available")
plt.ylabel("Number of Restaurants")
plt.xticks([0, 1], ['No', 'Yes'])
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-1183573857.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='has_table_booking', data=df, palette='pastel')

# %%
#Impact of Table Booking on Ratings
plt.figure(figsize=(6, 4))
sns.boxplot(x='has_table_booking', y='aggregate_rating', data=df, palette='coolwarm')
plt.title("Table Booking Availability vs Ratings")
plt.xlabel("Table Booking Available")
plt.ylabel("Aggregate Rating")
plt.xticks([0, 1], ['No', 'Yes'])
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-2063565270.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='has_table_booking', y='aggregate_rating', data=df, palette='coolwarm')

# %%
 #Identify Top Restaurant Chains by Number of Outlets
 # Count number of outlets per restaurant name
top_chains = df['name'].value_counts().head(10)
plt.figure(figsize=(10, 5))
sns.barplot(x=top_chains.values, y=top_chains.index, palette='cubehelix')
plt.title("Top 10 Restaurant Chains by Number of Outlets")
plt.xlabel("Number of Outlets")
plt.ylabel("Restaurant Name")
plt.show()
# Out:
# /tmp/ipython-input-640698935.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_chains.values, y=top_chains.index, palette='cubehelix')

# %%
#Explore Ratings of These Top Chains
# Filter data for only top 10 restaurant chains
top_chain_names = top_chains.index.tolist()
top_chain_data = df[df['name'].isin(top_chain_names)]

# Plot average rating of each top chain
chain_avg_ratings = top_chain_data.groupby('name')['aggregate_rating'].mean().sort_values(ascending=False)

plt.figure(figsize=(8, 4))
sns.barplot(x=chain_avg_ratings.values, y=chain_avg_ratings.index, palette='coolwarm')
plt.title("Average Rating of Top 10 Restaurant Chains")
plt.xlabel("Average Rating")
plt.ylabel("Restaurant Name")
plt.show()
# Out:
# /tmp/ipython-input-481680820.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=chain_avg_ratings.values, y=chain_avg_ratings.index, palette='coolwarm')

# %%
# Optional: Show number of votes for each chain
chain_votes = top_chain_data.groupby('name')['votes'].sum().sort_values(ascending=False)
print("Total Votes per Chain:\n", chain_votes)
# Out:
# Total Votes per Chain:
#  name
# Domino's Pizza        1467693
# Barbeque Nation        816676
# KFC                    754518
# Burger King            392010
# Pizza Hut              333958
# Subway                 199120
# McDonald's             194652
# The Chocolate Room     114327
# Keventers               63656
# Cafe Coffee Day         43597
# Name: votes, dtype: int64

# %%
flat_highlights = (df['highlights'].dropna().str.split(',').explode().str.strip())
top_features = flat_highlights.value_counts().head(10)

# Plot
plt.figure(figsize=(10, 4))
sns.barplot(x=top_features.values, y=top_features.index, palette='Blues_d')
plt.title("Top 10 Most Common Restaurant Features")
plt.xlabel("Number of Restaurants")
plt.ylabel("Feature")
plt.show()
# Out:
# /tmp/ipython-input-3681742919.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_features.values, y=top_features.index, palette='Blues_d')

# %%
#Correlation Between a Feature (e.g., Wi-Fi) and Ratings
# Choose a feature to test
feature_to_test = 'Wi-Fi'

# Create a new column indicating if the feature exists
df['has_wifi'] = df['highlights'].apply(lambda x: feature_to_test in x)

# Compare ratings using boxplot
plt.figure(figsize=(6, 4))
sns.boxplot(x='has_wifi', y='aggregate_rating', data=df, palette='Set2')
plt.title(f"Restaurant Ratings: With vs Without '{feature_to_test}'")
plt.xlabel(f"'{feature_to_test}' Available")
plt.ylabel("Aggregate Rating")
plt.xticks([0, 1], ['No', 'Yes'])
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-539986683.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='has_wifi', y='aggregate_rating', data=df, palette='Set2')

# %%
#Word Cloud from Reviews
#Create a Word Cloud from Review Text (Assuming a reviews column exists)
from wordcloud import WordCloud

# Assuming you have a review column:
#reviews_text = df['reviews'].dropna().str.cat(sep=' ')

# Since reviews don't exist, we simulate with rating_text
reviews_text = df['rating_text'].dropna().str.cat(sep=' ')

# Generate Word Cloud
wordcloud = WordCloud(width=1000, height=500, background_color='white', colormap='viridis').generate(reviews_text)

# Plot
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud from Rating Text")
plt.show()

# %%
#Sentiment Classification Based on rating_text
# Simple sentiment mapping
def classify_sentiment(rating_text):
    if rating_text in ['Excellent', 'Very Good']:
        return 'Positive'
    elif rating_text in ['Average']:
        return 'Neutral'
    else:
        return 'Negative'

df['sentiment'] = df['rating_text'].apply(classify_sentiment)
#ploting graph
plt.figure(figsize=(6, 4))
sns.countplot(x='sentiment', data=df, palette='Set1')
plt.title("Customer Sentiment Based on Ratings")
plt.xlabel("Sentiment")
plt.ylabel("Number of Restaurants")
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-2319561864.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sentiment', data=df, palette='Set1')
